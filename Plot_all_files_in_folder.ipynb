# %%
import imp
import os
imp.reload(modules)
import modules
from modules import Rose
from modules import Rose_all
imp.reload(modules)
# Out:
# <module 'modules' from 'C:\\Users\\x53965mb\\Python\\Fieldwork\\modules.py'>

# %%
#load all datafiles in the folder
files = os.listdir()
files_csv = [f for f in files if f[-3:] == 'csv']
print(files_csv)
print(os.getcwd())

for x in files_csv:
    Rose(filename = x, bins = 12, save = 'yes')
# Out:
# ['PB_pci_1E.csv', 'PB_pci_1f.csv', 'PB_pci_1G.csv', 'PB_pci_1H.csv', 'PB_pci_1i.csv', 'PB_pci_2A-2C.csv', 'PB_pci_3B.csv', 'PB_pci_3C.csv', 'PB_pci_3E.csv']
# C:\Users\x53965mb\Python\Fieldwork\Data

# %%
Rose_all(bins=12, save = 'yes')
